# %%
from labintfactory.photometer.absorbance import Absorbance
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['animation.html']='jshtml'
application=Absorbance()
application.draw_interface()
